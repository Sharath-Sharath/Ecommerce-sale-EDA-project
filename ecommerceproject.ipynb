# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("ecommerce_sales_dataset.csv")
print(df)
# Out:
#      OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0       1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1       1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2       1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3       1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4       1005  2023-01-05  Customer_61  Electronics     Mobiles         9
# ..       ...         ...          ...          ...         ...       ...
# 495     1496  2024-05-10  Customer_63    Furniture       Sofas         2
# 496     1497  2024-05-11  Customer_69    Furniture       Sofas         7
# 497     1498  2024-05-12  Customer_22     Clothing       Shoes         6
# 498     1499  2024-05-13  Customer_93     Clothing       Shoes         4
# 499     1500  2024-05-14  Customer_67    Furniture      Chairs         7
#
#      UnitPrice  TotalSales  Discount   Profit Region
# ...

# %%
#basic commands
df.head()
# Out:
#    OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0     1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1     1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2     1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3     1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4     1005  2023-01-05  Customer_61  Electronics     Mobiles         9
#
#    UnitPrice  TotalSales  Discount   Profit Region
# 0      39.67       79.34      0.24    14.99   East
# 1     314.85     2833.65      0.08   534.29  South
# 2     707.63     1415.26      0.25   260.46   East
# 3     209.83     1049.15      0.15   214.17  South
# 4     676.70     6090.30       NaN  1007.42  North

# %%
df.tail()
# Out:
#      OrderID   OrderDate CustomerName   Category SubCategory  Quantity  \
# 495     1496  2024-05-10  Customer_63  Furniture       Sofas         2
# 496     1497  2024-05-11  Customer_69  Furniture       Sofas         7
# 497     1498  2024-05-12  Customer_22   Clothing       Shoes         6
# 498     1499  2024-05-13  Customer_93   Clothing       Shoes         4
# 499     1500  2024-05-14  Customer_67  Furniture      Chairs         7
#
#      UnitPrice  TotalSales  Discount   Profit Region
# 495     584.18     1168.36      0.18   244.26   West
# 496     565.87     3961.09      0.25   856.00   West
# 497     565.05     3390.30      0.30   535.14   East
# 498     607.45     2429.80      0.09   496.77   West
# 499     679.70     4757.90      0.29  1051.17  South

# %%
df.shape
# Out:
# (500, 11)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerName', 'Category', 'SubCategory',
#        'Quantity', 'UnitPrice', 'TotalSales', 'Discount', 'Profit', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       500 non-null    int64
#  1   OrderDate     500 non-null    object
#  2   CustomerName  478 non-null    object
#  3   Category      500 non-null    object
#  4   SubCategory   500 non-null    object
#  5   Quantity      500 non-null    int64
#  6   UnitPrice     500 non-null    float64
#  7   TotalSales    500 non-null    float64
#  8   Discount      473 non-null    float64
#  9   Profit        481 non-null    float64
#  10  Region        500 non-null    object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 43.1+ KB

# %%
df.describe()
# Out:
#            OrderID   Quantity  UnitPrice   TotalSales    Discount       Profit
# count   500.000000  500.00000  500.00000   500.000000  473.000000   481.000000
# mean   1250.500000    5.00000  509.02178  2545.298740    0.147505   510.711081
# std     144.481833    2.66048  283.49577  2137.748868    0.086235   439.838118
# min    1001.000000    1.00000   13.19000    29.000000    0.000000     6.030000
# 25%    1125.750000    3.00000  258.34250   773.225000    0.080000   155.840000
# 50%    1250.500000    5.00000  527.83000  1953.270000    0.150000   382.310000
# 75%    1375.250000    7.00000  740.07750  3679.042500    0.220000   747.050000
# max    1500.000000    9.00000  999.42000  8731.890000    0.300000  1950.380000

# %%
#checking data
df.isnull().sum
# Out:
# <bound method DataFrame.sum of      OrderID  OrderDate  CustomerName  Category  SubCategory  Quantity  \
# 0      False      False         False     False        False     False
# 1      False      False         False     False        False     False
# 2      False      False         False     False        False     False
# 3      False      False         False     False        False     False
# 4      False      False         False     False        False     False
# ..       ...        ...           ...       ...          ...       ...
# 495    False      False         False     False        False     False
# 496    False      False         False     False        False     False
# 497    False      False         False     False        False     False
# 498    False      False         False     False        False     False
# 499    False      False         False     False        False     False
#
#      UnitPrice  TotalSales  Discount  Profit  Region
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.nunique()
# Out:
# OrderID         500
# OrderDate       500
# CustomerName     99
# Category          3
# SubCategory       9
# Quantity          9
# UnitPrice       498
# TotalSales      500
# Discount         31
# Profit          480
# Region            4
# dtype: int64

# %%
#selected data:
df.loc[28]
# Out:
# OrderID                1029
# OrderDate        2023-01-29
# CustomerName    Customer_89
# Category          Furniture
# SubCategory          Chairs
# Quantity                  3
# UnitPrice            661.27
# TotalSales          1983.81
# Discount               0.12
# Profit               410.53
# Region                North
# Name: 28, dtype: object

# %%
df.iloc[15]
# Out:
# OrderID                1016
# OrderDate        2023-01-16
# CustomerName    Customer_53
# Category           Clothing
# SubCategory          Shirts
# Quantity                  2
# UnitPrice             502.2
# TotalSales           1004.4
# Discount               0.03
# Profit                177.8
# Region                 East
# Name: 15, dtype: object

# %%
df["Category"]
# Out:
# 0         Clothing
# 1        Furniture
# 2      Electronics
# 3         Clothing
# 4      Electronics
#           ...
# 495      Furniture
# 496      Furniture
# 497       Clothing
# 498       Clothing
# 499      Furniture
# Name: Category, Length: 500, dtype: object

# %%
df[["Category","SubCategory"]]
# Out:
#         Category SubCategory
# 0       Clothing      Shirts
# 1      Furniture       Sofas
# 2    Electronics     Laptops
# 3       Clothing      Shirts
# 4    Electronics     Mobiles
# ..           ...         ...
# 495    Furniture       Sofas
# 496    Furniture       Sofas
# 497     Clothing       Shoes
# 498     Clothing       Shoes
# 499    Furniture      Chairs
#
# [500 rows x 2 columns]

# %%
#basic analysis
df["Profit"].sum()
# Out:
# np.float64(245652.02999999997)

# %%
df["Region"].value_counts()
# Out:
# Region
# North    131
# East     129
# South    123
# West     117
# Name: count, dtype: int64

# %%
df["Quantity"].mean()
# Out:
# np.float64(5.0)

# %%
df["Profit"].max()
# Out:
# 1950.38

# %%
df["Profit"].min()
# Out:
# 6.03

# %%
#filtering rows:
df[df["Quantity"]<=5]
# Out:
#      OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0       1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 2       1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3       1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 7       1008  2023-01-08  Customer_87  Electronics     Laptops         1
# 8       1009  2023-01-09  Customer_75    Furniture       Sofas         1
# ..       ...         ...          ...          ...         ...       ...
# 487     1488  2024-05-02  Customer_34  Electronics     Laptops         2
# 489     1490  2024-05-04  Customer_48  Electronics  Headphones         2
# 491     1492  2024-05-06   Customer_1    Furniture      Tables         2
# 495     1496  2024-05-10  Customer_63    Furniture       Sofas         2
# 498     1499  2024-05-13  Customer_93     Clothing       Shoes         4
#
#      UnitPrice  TotalSales  Discount  Profit Region
# ...

# %%
df[df["Region"]=="East"]
# Out:
#      OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0       1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 2       1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 6       1007  2023-01-07  Customer_83     Clothing       Jeans         8
# 15      1016  2023-01-16  Customer_53     Clothing      Shirts         2
# 17      1018  2023-01-18  Customer_88    Furniture      Chairs         3
# ..       ...         ...          ...          ...         ...       ...
# 485     1486  2024-04-30  Customer_58     Clothing       Shoes         4
# 487     1488  2024-05-02  Customer_34  Electronics     Laptops         2
# 489     1490  2024-05-04  Customer_48  Electronics  Headphones         2
# 490     1491  2024-05-05  Customer_89     Clothing       Jeans         9
# 497     1498  2024-05-12  Customer_22     Clothing       Shoes         6
#
#      UnitPrice  TotalSales  Discount  Profit Region
# ...

# %%
df[(df["Category"]=="Clothing")&(df["SubCategory"]=="Shirts")]
# Out:
#      OrderID   OrderDate CustomerName  Category SubCategory  Quantity  \
# 0       1001  2023-01-01  Customer_52  Clothing      Shirts         2
# 3       1004  2023-01-04  Customer_72  Clothing      Shirts         5
# 10      1011  2023-01-11  Customer_88  Clothing      Shirts         8
# 12      1013  2023-01-13  Customer_24  Clothing      Shirts         7
# 14      1015  2023-01-15  Customer_22  Clothing      Shirts         3
# 15      1016  2023-01-16  Customer_53  Clothing      Shirts         2
# 69      1070  2023-03-11  Customer_36  Clothing      Shirts         7
# 76      1077  2023-03-18  Customer_54  Clothing      Shirts         1
# 84      1085  2023-03-26  Customer_62  Clothing      Shirts         7
# 106     1107  2023-04-17  Customer_45  Clothing      Shirts         9
# 108     1109  2023-04-19  Customer_89  Clothing      Shirts         9
# 138     1139  2023-05-19  Customer_86  Clothing      Shirts         1
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#            OrderID   Quantity  UnitPrice   TotalSales    Discount       Profit
# count   500.000000  500.00000  500.00000   500.000000  473.000000   481.000000
# mean   1250.500000    5.00000  509.02178  2545.298740    0.147505   510.711081
# std     144.481833    2.66048  283.49577  2137.748868    0.086235   439.838118
# min    1001.000000    1.00000   13.19000    29.000000    0.000000     6.030000
# 25%    1125.750000    3.00000  258.34250   773.225000    0.080000   155.840000
# 50%    1250.500000    5.00000  527.83000  1953.270000    0.150000   382.310000
# 75%    1375.250000    7.00000  740.07750  3679.042500    0.220000   747.050000
# max    1500.000000    9.00000  999.42000  8731.890000    0.300000  1950.380000

# %%
df["Profit"].median()
# Out:
# 382.31

# %%
df["TotalSales"].mean()
# Out:
# np.float64(2545.2987399999997)

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    187
# Clothing       161
# Furniture      152
# Name: count, dtype: int64

# %%
df["SubCategory"].value_counts()
# Out:
# SubCategory
# Headphones    65
# Mobiles       62
# Laptops       60
# Jeans         59
# Shoes         53
# Chairs        52
# Sofas         50
# Tables        50
# Shirts        49
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#              OrderID  Quantity  UnitPrice  TotalSales  Discount    Profit
# OrderID     1.000000 -0.026891  -0.002406   -0.009724 -0.019008 -0.004369
# Quantity   -0.026891  1.000000   0.000252    0.641896 -0.026961  0.625815
# UnitPrice  -0.002406  0.000252   1.000000    0.681958 -0.021622  0.675971
# TotalSales -0.009724  0.641896   0.681958    1.000000 -0.024465  0.974209
# Discount   -0.019008 -0.026961  -0.021622   -0.024465  1.000000 -0.025555
# Profit     -0.004369  0.625815   0.675971    0.974209 -0.025555  1.000000

# %%
df.head()
# Out:
#    OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0     1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1     1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2     1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3     1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4     1005  2023-01-05  Customer_61  Electronics     Mobiles         9
#
#    UnitPrice  TotalSales  Discount   Profit Region
# 0      39.67       79.34      0.24    14.99   East
# 1     314.85     2833.65      0.08   534.29  South
# 2     707.63     1415.26      0.25   260.46   East
# 3     209.83     1049.15      0.15   214.17  South
# 4     676.70     6090.30       NaN  1007.42  North

# %%
#visualization:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plot=sns.barplot(data=df,x="Region",hue="Region",color="blue",palette="coolwarm")
plt.title("customername with category")
plt.xlabel("Region")
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0     1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1     1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2     1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3     1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4     1005  2023-01-05  Customer_61  Electronics     Mobiles         9
#
#    UnitPrice  TotalSales  Discount   Profit Region
# 0      39.67       79.34      0.24    14.99   East
# 1     314.85     2833.65      0.08   534.29  South
# 2     707.63     1415.26      0.25   260.46   East
# 3     209.83     1049.15      0.15   214.17  South
# 4     676.70     6090.30       NaN  1007.42  North

# %%
df.tail()
# Out:
#      OrderID   OrderDate CustomerName   Category SubCategory  Quantity  \
# 495     1496  2024-05-10  Customer_63  Furniture       Sofas         2
# 496     1497  2024-05-11  Customer_69  Furniture       Sofas         7
# 497     1498  2024-05-12  Customer_22   Clothing       Shoes         6
# 498     1499  2024-05-13  Customer_93   Clothing       Shoes         4
# 499     1500  2024-05-14  Customer_67  Furniture      Chairs         7
#
#      UnitPrice  TotalSales  Discount   Profit Region
# 495     584.18     1168.36      0.18   244.26   West
# 496     565.87     3961.09      0.25   856.00   West
# 497     565.05     3390.30      0.30   535.14   East
# 498     607.45     2429.80      0.09   496.77   West
# 499     679.70     4757.90      0.29  1051.17  South

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.barh(df["Category"], df["Profit"], color="skyblue")
# Out:
# <BarContainer object of 500 artists>

# %%
plot=sns.barplot(data=df,x="SubCategory",hue="Region",color="blue",palette="coolwarm")

# %%
sns.histplot(data=df,x="Profit",bins=5,color="blue")
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %%
sns.scatterplot(data=df,x="SubCategory",y="OrderDate",hue="SubCategory",color="blue")
# Out:
# <Axes: xlabel='SubCategory', ylabel='OrderDate'>

# %%
df.head()
# Out:
#    OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0     1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1     1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2     1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3     1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4     1005  2023-01-05  Customer_61  Electronics     Mobiles         9
#
#    UnitPrice  TotalSales  Discount   Profit Region
# 0      39.67       79.34      0.24    14.99   East
# 1     314.85     2833.65      0.08   534.29  South
# 2     707.63     1415.26      0.25   260.46   East
# 3     209.83     1049.15      0.15   214.17  South
# 4     676.70     6090.30       NaN  1007.42  North

# %%
df.head()
# Out:
#    OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0     1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1     1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2     1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3     1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4     1005  2023-01-05  Customer_61  Electronics     Mobiles         9
#
#    UnitPrice  TotalSales  Discount   Profit Region
# 0      39.67       79.34      0.24    14.99   East
# 1     314.85     2833.65      0.08   534.29  South
# 2     707.63     1415.26      0.25   260.46   East
# 3     209.83     1049.15      0.15   214.17  South
# 4     676.70     6090.30       NaN  1007.42  North

# %%
sns.countplot(data=df,x="Category",y="Profit",hue="Category")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 sns.countplot(data=df,x="Category",y="Profit",hue="Category")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2629, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2627     y = 1 if list(x) else None
#    2628 elif x is not None and y is not None:
# -> 2629     raise TypeError("Cannot pass values for both `x` and `y`.")
#    2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    (...)   2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#
# TypeError: Cannot pass values for both `x` and `y`.

# %%
sns.histplot(data=df,x="UnitPrice",bins=10,color="blue")
plt.title("Unitprice")
plt.xlabel("UnitPrice")
plt.ylabel("Frequency")
plt.grid(axis="y",alpha=0.75)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 sns.histplot(data=df,x="UnitPrice",bins=10,color="blue")
#       2 plt.title("Unitprice")
#       3 plt.xlabel("UnitPrice")
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
#    1381         variables=dict(x=x, y=y, hue=hue, weights=weights),
#    1382     )
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("ecommerce_sales_dataset.csv")
sns.histplot(data=df,x="UnitPrice",bins=15,color="blue")
plt.title("Unitprice")
plt.xlabel("UnitPrice")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("ecommerce_sales_dataset.csv")
print(df)
# Out:
#      OrderID   OrderDate CustomerName     Category SubCategory  Quantity  \
# 0       1001  2023-01-01  Customer_52     Clothing      Shirts         2
# 1       1002  2023-01-02  Customer_93    Furniture       Sofas         9
# 2       1003  2023-01-03  Customer_15  Electronics     Laptops         2
# 3       1004  2023-01-04  Customer_72     Clothing      Shirts         5
# 4       1005  2023-01-05  Customer_61  Electronics     Mobiles         9
# ..       ...         ...          ...          ...         ...       ...
# 495     1496  2024-05-10  Customer_63    Furniture       Sofas         2
# 496     1497  2024-05-11  Customer_69    Furniture       Sofas         7
# 497     1498  2024-05-12  Customer_22     Clothing       Shoes         6
# 498     1499  2024-05-13  Customer_93     Clothing       Shoes         4
# 499     1500  2024-05-14  Customer_67    Furniture      Chairs         7
#
#      UnitPrice  TotalSales  Discount   Profit Region
# ...

# %%
df.shape
# Out:
# (500, 11)

# %%
sns.histplot(data=df,x="Quantity",bins=15,color="blue",kde=True)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.boxplot(data=df,x="Category",hue="Category",palette="Set3")
# Out:
# <Axes: xlabel='Category'>

# %%
sns.scatterplot(data=df,x="TotalSales",y="Discount",hue="Category")
# Out:
# <Axes: xlabel='TotalSales', ylabel='Discount'>

# %%
sns.lineplot(data=df,x="TotalSales",y="Discount",hue="Category")
# Out:
# <Axes: xlabel='TotalSales', ylabel='Discount'>

# %%
sns.violinplot(data=df,x="Profit",hue="Category")
# Out:
# <Axes: xlabel='Profit'>

# %%
sns.barplot(data=df,x="Profit",hue="Category")
# Out:
# <Axes: xlabel='Profit'>

# %%
sns.boxplot(data=df,x="Profit",hue="Category")
# Out:
# <Axes: xlabel='Profit'>
